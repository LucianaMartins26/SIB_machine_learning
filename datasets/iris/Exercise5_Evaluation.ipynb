# %% [markdown]
# __Exercise 5: Implementing PCA__

# %% [markdown]
# _Test the PCA class in a Jupyter notebook using the "iris.csv" dataset (classification)._

# %%
from SIB_machine_learning.src.si.io.csv_file import read_csv

file = read_csv('iris.csv', sep=',', features = True, label = True)

# %%
from SIB_machine_learning.src.decomposition.pca import PCA

pca = PCA(2)
pca.fit(file.X)
pca.transform(file.X)
# Out:
# array([[-2.68420713, -0.32660731],
#        [-2.71539062,  0.16955685],
#        [-2.88981954,  0.13734561],
#        [-2.7464372 ,  0.31112432],
#        [-2.72859298, -0.33392456],
#        [-2.27989736, -0.74778271],
#        [-2.82089068,  0.08210451],
#        [-2.62648199, -0.17040535],
#        [-2.88795857,  0.57079803],
#        [-2.67384469,  0.1066917 ],
#        [-2.50652679, -0.65193501],
#        [-2.61314272, -0.02152063],
#        [-2.78743398,  0.22774019],
#        [-3.22520045,  0.50327991],
#        [-2.64354322, -1.1861949 ],
#        [-2.38386932, -1.34475434],
#        [-2.6225262 , -0.81808967],
#        [-2.64832273, -0.31913667],
#        [-2.19907796, -0.87924409],
#        [-2.58734619, -0.52047364],
#        [-2.3105317 , -0.39786782],
#        [-2.54323491, -0.44003175],
#        [-3.21585769, -0.14161557],
#        [-2.30312854, -0.10552268],
#        [-2.35617109,  0.03120959],
#        [-2.50791723,  0.13905634],
#        [-2.469056  , -0.13788731],
# ...

# %%
pca = PCA(6)
pca.fit(file.X)
pca.transform(file.X)
# Out:
# array([[-2.68420713e+00, -3.26607315e-01,  2.15118370e-02,
#          1.00615724e-03],
#        [-2.71539062e+00,  1.69556848e-01,  2.03521425e-01,
#          9.96024240e-02],
#        [-2.88981954e+00,  1.37345610e-01, -2.47092410e-02,
#          1.93045428e-02],
#        [-2.74643720e+00,  3.11124316e-01, -3.76719753e-02,
#         -7.59552741e-02],
#        [-2.72859298e+00, -3.33924564e-01, -9.62296998e-02,
#         -6.31287327e-02],
#        [-2.27989736e+00, -7.47782713e-01, -1.74325619e-01,
#         -2.71468037e-02],
#        [-2.82089068e+00,  8.21045110e-02, -2.64251085e-01,
#         -5.00996251e-02],
#        [-2.62648199e+00, -1.70405349e-01,  1.58015103e-02,
#         -4.62817610e-02],
#        [-2.88795857e+00,  5.70798026e-01, -2.73354061e-02,
#         -2.66154143e-02],
#        [-2.67384469e+00,  1.06691704e-01,  1.91533300e-01,
#         -5.58909660e-02],
#        [-2.50652679e+00, -6.51935014e-01,  6.92749958e-02,
#         -1.66082478e-02],
# ...

# %%
pca = PCA(1)
pca.fit(file.X)
pca.transform(file.X)
# Out:
# array([[-2.68420713],
#        [-2.71539062],
#        [-2.88981954],
#        [-2.7464372 ],
#        [-2.72859298],
#        [-2.27989736],
#        [-2.82089068],
#        [-2.62648199],
#        [-2.88795857],
#        [-2.67384469],
#        [-2.50652679],
#        [-2.61314272],
#        [-2.78743398],
#        [-3.22520045],
#        [-2.64354322],
#        [-2.38386932],
#        [-2.6225262 ],
#        [-2.64832273],
#        [-2.19907796],
#        [-2.58734619],
#        [-2.3105317 ],
#        [-2.54323491],
#        [-3.21585769],
#        [-2.30312854],
#        [-2.35617109],
#        [-2.50791723],
#        [-2.469056  ],
#        [-2.56239095],
#        [-2.63982127],
#        [-2.63284791],
#        [-2.58846205],
#        [-2.41007734],
#        [-2.64763667],
#        [-2.59715948],
#        [-2.67384469],
#        [-2.86699985],
#        [-2.62522846],
#        [-2.67384469],
#        [-2.98184266],
#        [-2.59032303],
#        [-2.77013891],
# ...
